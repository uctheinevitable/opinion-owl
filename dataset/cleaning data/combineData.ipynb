# %%
import pandas as pd
import numpy as np

# %%
reddit = pd.read_csv("../data/reddit_labeled.csv")
semEval = pd.read_csv("../data/semEval_train.csv")

# %%
reddit.shape
# Out:
# (376, 3)

# %%
semEval.shape
# Out:
# (2358, 3)

# %%
data = pd.concat([reddit, semEval], ignore_index = True)

# %%
data.to_csv('../data/combined_train.csv')
